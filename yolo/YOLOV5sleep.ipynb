# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/visually_impaired/sleep_final.zip' -d '/content/drive/MyDrive/visually_impaired'
# Out:
# Archive:  /content/drive/MyDrive/visually_impaired/sleep_final.zip
#    creating: /content/drive/MyDrive/visually_impaired/sleep_final/train/
#    creating: /content/drive/MyDrive/visually_impaired/sleep_final/train/images/
#   inflating: /content/drive/MyDrive/visually_impaired/sleep_final/train/images/sleepinge02371.jpg
#   inflating: /content/drive/MyDrive/visually_impaired/sleep_final/train/images/sleepingf02202.jpg
#   inflating: /content/drive/MyDrive/visually_impaired/sleep_final/train/images/sleepingf02203.jpg
#   inflating: /content/drive/MyDrive/visually_impaired/sleep_final/train/images/sleepingf02204.jpg
#   inflating: /content/drive/MyDrive/visually_impaired/sleep_final/train/images/sleepingf02205.jpg
#   inflating: /content/drive/MyDrive/visually_impaired/sleep_final/train/images/sleepingf02206.jpg
#   inflating: /content/drive/MyDrive/visually_impaired/sleep_final/train/images/sleepingf02207.jpg
# ...

# %%
# %cd '/content/drive/MyDrive/visually_impaired'
# Out:
# /content/drive/MyDrive/visually_impaired

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16057, done.
# remote: Total 16057 (delta 0), reused 0 (delta 0), pack-reused 16057
# Receiving objects: 100% (16057/16057), 14.60 MiB | 2.39 MiB/s, done.
# Resolving deltas: 100% (11032/11032), done.

# %%
# %cd 'yolov5'
# %pip install -qr requirements.txt
# Out:
# /content/drive/MyDrive/visually_impaired/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 24.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.2/645.2 kB 36.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.

# %%
# %cd '/content/drive/MyDrive/visually_impaired/yolov5'
# Out:
# /content/drive/MyDrive/visually_impaired/yolov5

# %%
# !ls
# Out:
# benchmarks.py	 data	     LICENSE	      requirements.txt	tutorial.ipynb
# CITATION.cff	 detect.py   models	      segment		utils
# classify	 export.py   README.md	      setup.cfg		val.py
# CONTRIBUTING.md  hubconf.py  README.zh-CN.md  train.py

# %%
# !python train.py --img 640 --batch 16 --epochs 80 --data /content/drive/MyDrive/visually_impaired/custom.yaml --weights yolov5s.pt --cache
# Out:
# 2023-11-09 10:33:17.370503: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-09 10:33:17.370558: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-09 10:33:17.370597: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# %cd '/content/drive/MyDrive/v/yolov5'
# Out:
# /content/drive/MyDrive/CARSCRATCH/yolov5

# %%
# !python detect.py --weights /content/drive/MyDrive/visually_impaired/yolov5/runs/train/exp2/weights/best.pt  --img 640 --conf 0.25 --source /content/drive/MyDrive/visually_impaired/walk.mp4
# Out:
# detect: weights=['/content/drive/MyDrive/visually_impaired/yolov5/runs/train/exp2/weights/best.pt'], source=/content/drive/MyDrive/visually_impaired/walk.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-240-g84ec8b5 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# video 1/1 (1/276) /content/drive/MyDrive/visually_impaired/walk.mp4: 384x640 (no detections), 58.4ms
# video 1/1 (2/276) /content/drive/MyDrive/visually_impaired/walk.mp4: 384x640 (no detections), 10.3ms
# ...
